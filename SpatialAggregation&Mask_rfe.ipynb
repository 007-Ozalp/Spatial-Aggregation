# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h3>SPATIAL AGGREGATION & MASK: RFE</h3></div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='TOC_TOP'></a>Contents
#
# </div>
#
# [Section 1](#section1) Import Libraries
# <hr>
# </div>
#
# [Section 2](#section2) Data Selection
# <hr>
# </div>
#
# [Section 3](#section3) Spatial Aggregation
# <hr>
# </div>
#
# [Section 4](#section4) Mask Area
# <hr>
# </div>
#
# [Section 5](#section5) Plot
# <hr>
#
# <hr>

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section1'></a>1. Import Libraries
# [Back to top](#TOC_TOP)
#
# </div>

# %%
import matplotlib.pyplot as plt
import xarray 
import rioxarray
import regionmask
import pandas as pd
import jn_functions as jn

import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')
# Out:
# /home/ozlem/anaconda3/envs/geocat/lib/python3.10/site-packages/geopandas/_compat.py:123: UserWarning: The Shapely GEOS version (3.8.0-CAPI-1.13.1 ) is incompatible with the GEOS version PyGEOS was compiled with (3.10.4-CAPI-1.16.2). Conversions between both will be slow.
#   warnings.warn(

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section2'></a>2. Data Selection
# [Back to top](#TOC_TOP)
#
# </div>

# %% [markdown]
# **Define Input File Names and outputs:**
#
# **The desired <font color='red'> **resolution** </font> parameter:**
#
# **The <font color='red'> **ROI** </font> Area for Africa continent:**

# %%
spatial_resolution=1.0/2.0
roi= [-36, 38, -19, 52]

# %%
data_input_1 = '20101021_tamsat-rfe_10d_TAMSAT-Africa-4km_3.1.tif'
data_resampled_1=f'20101021_tamsat-rfe_'+ 'CommonAfrica_' + str(spatial_resolution)+'D'+'.tif'
data_resampled_mask_1='20101021_tamsat-rfe_'+ 'CommonAfrica_' + str(spatial_resolution)+'D_mask'+'.tif'



data_input_2 = '20101021_chirps-dekad_10d_CHIRP-Africa-5km_2.0.tif'
data_resampled_2='20101021_chirps-dekad_'+ 'CommonAfrica_' + str(spatial_resolution)+'D'+'.tif'
data_resampled_mask_2='20101021_chirps-dekad_'+ 'CommonAfrica_' + str(spatial_resolution)+'D_mask'+'.tif'



data_input_3 = '20101021_fewsnet-rfe_10d_FEWSNET-Africa-8km_2.0.tif'
data_resampled_3='20101021_fewsnet-rfe_'+ 'CommonAfrica_'+ str(spatial_resolution)+'D'+'.tif'
data_resampled_mask_3='20101021_fewsnet-rfe_'+ 'CommonAfrica_'+ str(spatial_resolution)+'D_mask'+'.tif'



data_input_4 = '20101021_arc2-rain_10d_ARC2-Africa-11km_2.0.tif'
data_resampled_4='20101021_arc2-rain_'+ 'CommonAfrica_'+ str(spatial_resolution)+'D'+'.tif'
data_resampled_mask_4='20101021_arc2-rain_'+ 'CommonAfrica_'+ str(spatial_resolution)+'D_mask'+'.tif'

# %%
input_1 = rioxarray.open_rasterio(data_input_1, masked=True)
input_2 = rioxarray.open_rasterio(data_input_2, masked=True)
input_3 = rioxarray.open_rasterio(data_input_3, masked=True)
input_4 = rioxarray.open_rasterio(data_input_4, masked=True)

input_1#,input_2,input_3,input_4
# Out:
# <xarray.DataArray (band: 1, y: 1974, x: 1894)>
# [3738756 values with dtype=float32]
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -18.99 -18.96 -18.92 -18.88 ... 51.92 51.96 51.99
#   * y            (y) float64 38.01 37.97 37.93 37.89 ... -35.91 -35.94 -35.98
#     spatial_ref  int64 0
# Attributes: (12/26)
#     AREA_OR_POINT:              Area
#     eStation2_category:         rainfall
#     eStation2_comp_time:        2021-03-15 10:35:48
#     eStation2_conversion:       Phys = DN * scaling_factor + scaling_offset
#     eStation2_date:             20101021
#     eStation2_date_format:      YYYYMMDD
#     ...                         ...
#     eStation2_scaling_offset:   0.0
#     eStation2_subdir:           tamsat-rfe/3.1/TAMSAT-Africa-4km/tif/10d/
#     eStation2_subProduct:       10d
#     eStation2_unit:             mm
#     scale_factor:               1.0
#     add_offset:                 0.0

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section3'></a>3. Spatial Aggregation
# [Back to top](#TOC_TOP)
#
# </div>

# %% [markdown]
# **The two data are spatially-aggregated at <font color='red'> **0.05$^{\circ}$** </font> within the same size and same geographical extension.**

# %%
resampling_1 = jn.Spatial_Aggregation(spatial_resolution,roi,data_input_1, data_resampled_1)
# Out:
# Resampled shape: (148, 142)
# Resampled resolution: (0.5, -0.5)
# Resampled resampled bounds: (-19.0, -36.0, 52.0, 38.0)

# %%
resampling_2 = jn.Spatial_Aggregation(spatial_resolution,roi,data_input_2, data_resampled_2)
# Out:
# Resampled shape: (148, 142)
# Resampled resolution: (0.5, -0.5)
# Resampled resampled bounds: (-19.0, -36.0, 52.0, 38.0)

# %%
resampling_3 = jn.Spatial_Aggregation(spatial_resolution,roi,data_input_3, data_resampled_3)
# Out:
# Resampled shape: (148, 142)
# Resampled resolution: (0.5, -0.5)
# Resampled resampled bounds: (-19.0, -36.0, 52.0, 38.0)

# %%
resampling_4 = jn.Spatial_Aggregation(spatial_resolution,roi,data_input_4, data_resampled_4)
# Out:
# Resampled shape: (148, 142)
# Resampled resolution: (0.5, -0.5)
# Resampled resampled bounds: (-19.0, -36.0, 52.0, 38.0)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section4'></a>4. Mask Area
# [Back to top](#TOC_TOP)
#
# </div>

# %% [markdown]
# In this section the <a href="https://regionmask.readthedocs.io/en/v0.5.0/notebooks/mask_xarray.html">regionmask</a> package is  used to create masks of geographic regions for arbitrary longitude and latitude grids inside the function <font color='red'> ****Mask_Area_Plot**** </font>. Hence, at first step the function:
#
# 1. reads the tiff files in <a href="https://docs.xarray.dev/en/stable/">xarray</a> to compute the arithmetic mean along the labeled coordinates to define them for the <font color='teal'> **regionmask**.
#
# 2. then read the csv format file in <a href="https://pandas.pydata.org/docs/getting_started/index.html#getting-started">pandas</a>  **clip** </font>the tiff files by
# <a href="https://pygeos.readthedocs.io/en/stable/installation.html">pygeos</a> geometry.
#
# 3. Finally, save file. **

# %%
file_roi= pd.read_csv('AFRICA_MASK.csv')

# %%
mask_1=jn.Mask_Area_Plot(data_resampled_1,file_roi,data_resampled_mask_1)
mask_2=jn.Mask_Area_Plot(data_resampled_2,file_roi,data_resampled_mask_2)
mask_3=jn.Mask_Area_Plot(data_resampled_3,file_roi,data_resampled_mask_3)
mask_4=jn.Mask_Area_Plot(data_resampled_4,file_roi,data_resampled_mask_4)

# %% [markdown]
# <div class="alert alert-info" role="alert">
#
# ## <a id='section5'></a>5. Plot
# [Back to top](#TOC_TOP)
#
# </div>

# %%
read_mask_1=xarray.open_dataset(data_resampled_mask_1)
read_mask_2=xarray.open_dataset(data_resampled_mask_2)
read_mask_3=xarray.open_dataset(data_resampled_mask_3)
read_mask_4=xarray.open_dataset(data_resampled_mask_4)

# %%
read_mask_1#,read_mask_2,read_mask_3,read_mask_4
# Out:
# <xarray.Dataset>
# Dimensions:      (band: 1, x: 142, y: 148)
# Coordinates:
#   * band         (band) int64 1
#   * x            (x) float64 -18.75 -18.25 -17.75 -17.25 ... 50.75 51.25 51.75
#   * y            (y) float64 37.75 37.25 36.75 36.25 ... -34.75 -35.25 -35.75
#     spatial_ref  int64 ...
# Data variables:
#     band_data    (band, y, x) float32 ...

# %%
plt.rcParams["figure.figsize"] = [16, 8]
plt.rcParams["figure.autolayout"] = False

fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True,gridspec_kw={'width_ratios': [0.8, 1]})

fig.add_subplot(111, frameon=False)

# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)


plot1=read_mask_1.band_data.plot(ax=ax1,cmap='terrain_r',vmin=0,vmax=250,add_colorbar=False)

plot2=read_mask_2.band_data.plot(ax=ax2,cmap='terrain_r',vmin=0,vmax=250,add_colorbar=False)

fig.suptitle('RFE',x=0.49,fontsize = 20,weight='bold')
ax1.set_title('TAMSAT',fontsize = 16)
ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_title('CHIRP',fontsize = 16)
ax2.set_ylabel('')
ax2.set_xlabel('')


plt.xlabel("\nLONGITUDE",x=0.45,size=18)
plt.ylabel("LATITUDE",size=18)

cbar2 = plt.colorbar(plot2,ax=ax2)
cbar2.set_label('\nRFE[mm]',labelpad=+38, rotation=270,size=12)

plt.autoscale()
plt.tight_layout()

plt.show()

# %%
plt.rcParams["figure.figsize"] = [16, 8]
plt.rcParams["figure.autolayout"] = False

fig, (ax1, ax2) = plt.subplots(ncols=2,sharex=True,sharey=True,gridspec_kw={'width_ratios': [0.8, 1]})

fig.add_subplot(111, frameon=False)

# hide tick and tick label of the big axis
plt.tick_params(labelcolor='none', which='both', top=False, bottom=False, left=False, right=False)


plot1=read_mask_3.band_data.plot(ax=ax1,cmap='terrain_r',vmin=0,vmax=250,add_colorbar=False)

plot2=read_mask_4.band_data.plot(ax=ax2,cmap='terrain_r',vmin=0,vmax=250,add_colorbar=False)


fig.suptitle('RFE',x=0.49,fontsize = 20,weight='bold')
ax1.set_title('FEWSNET',fontsize = 16)
ax1.set_ylabel('')
ax1.set_xlabel('')

ax2.set_title('ARC2',fontsize = 16)
ax2.set_ylabel('')
ax2.set_xlabel('')


plt.xlabel("\nLONGITUDE",x=0.45,size=18)
plt.ylabel("LATITUDE",size=18)

cbar2 = plt.colorbar(plot2,ax=ax2)
cbar2.set_label('\nRFE[mm]',labelpad=+38, rotation=270,size=12)

plt.autoscale()
plt.tight_layout()

plt.show()
